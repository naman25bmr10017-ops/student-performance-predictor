# %%
import pandas as pd
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load dataset
data = pd.read_csv('../data/student_data.csv')

# Features and target
X = data[['study_hours', 'attendance', 'sleep_hours']]
y = data['marks']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# 🔽 Take input from user (with clear instructions)
print("\n--- Student Performance Predictor ---")
print("Please enter the following details:\n")

study_hours = float(input("Enter study hours per day (e.g., 5): "))
attendance = float(input("Enter attendance percentage (0 to 100): "))
sleep_hours = float(input("Enter sleep hours per day (e.g., 6-8): "))

# Convert input into DataFrame
new_data = pd.DataFrame([[study_hours, attendance, sleep_hours]],
                        columns=['study_hours', 'attendance', 'sleep_hours'])

# Predict
prediction = model.predict(new_data)

print("\nPredicted Marks:", round(prediction[0], 2))
# Out:
# --- Student Performance Predictor ---
# Please enter the following details:
# Enter study hours per day (e.g., 5):  7
# Enter attendance percentage (0 to 100):  90
# Enter sleep hours per day (e.g., 6-8):  6
# Predicted Marks: 80.0

# %%
pd.read_csv('../data/student_data.csv')
# Out:
#    study_hours  attendance  sleep_hours  marks
# 0            2          60            6     50
# 1            3          65            6     55
# 2            4          70            7     60
# 3            5          75            7     65
# 4            6          80            7     70
# 5            7          85            8     75
# 6            8          90            8     80
# 7            1          50            5     40
# 8            9          95            8     85
# 9           10         100            9     90
